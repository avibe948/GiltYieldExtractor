# %%
import datetime

# %%
bond_source_url = 'https://www.hl.co.uk/shares/corporate-bonds-gilts/bond-prices/uk-gilts?column=coupon&order=desc'

# %%
import pandas as pd

# Set the URL to extract the data from
url = bond_source_url
# Use pandas to extract the tables from the URL
tables = pd.read_html(url)
# Select the first table, which contains the bond data
bond_data = tables[0]
# Print the first 10 rows of the bond data
print(bond_data.head(10))
# Out:
#                                                    Issuer  Coupon (%)  \
# 0     Treasury 6% 07/12/2028 GBP | GB0002404191 | 0240419        6.00
# 1     Treasury 5% 07/03/2025 GBP | GB0030880693 | 3088069        5.00
# 2  Treasury 4.75% 07/12/2030 GBP | GB00B24FF097 | B24FF09        4.75
# 3  Treasury 4.75% 07/12/2038 GBP | GB00B00NY175 | B00NY17        4.75
# 4   Treasury 4.5% 07/09/2034 GBP | GB00B52WS153 | B52WS15        4.50
# 5   Treasury 4.5% 07/12/2042 GBP | GB00B1VWPJ53 | B1VWPJ5        4.50
# 6  Treasury 4.25% 07/09/2039 GBP | GB00B3KJDS62 | B3KJDS6        4.25
# 7  Treasury 4.25% 07/12/2049 GBP | GB00B39R3707 | B39R370        4.25
# 8  Treasury 4.25% 07/12/2027 GBP | GB00B16NNR78 | B16NNR7        4.25
# 9  Treasury 4.25% 07/12/2046 GBP | GB00B128DP45 | B128DP4        4.25
#
#            Maturity    Price                  Actions
# 0   7 December 2028  113.740  View factsheet Deal now
# 1      7 March 2025  102.420  View factsheet Deal now
# 2   7 December 2030  109.760  View factsheet Deal now
# 3   7 December 2038  112.530  View factsheet Deal now
# 4  7 September 2034  109.590  View factsheet Deal now
# 5   7 December 2042  110.185  View factsheet Deal now
# 6  7 September 2039  106.240  View factsheet Deal now
# 7   7 December 2049  107.850  View factsheet Deal now
# 8   7 December 2027  104.110  View factsheet Deal now
# 9   7 December 2046  106.945  View factsheet Deal now

# %%
bond_data.columns
# Out:
# Index(['Issuer', 'Coupon (%)', 'Maturity', 'Price', 'Actions'], dtype='object')

# %%
import pandas as pd

url = "https://www.hl.co.uk/shares/corporate-bonds-gilts/bond-prices/uk-gilts?column=coupon&order=desc"

bond_data = pd.read_html(url)[0]

bond_data['ShortName'] = bond_data['Issuer'].apply(lambda x: x.split('|')[1].strip())
bond_data["Price"] = bond_data["Price"]
bond_data["Maturity"] = pd.to_datetime(bond_data["Maturity"], format="%d %B %Y")
bond_data['Ttm'] = (bond_data['Maturity'] - pd.to_datetime('today')).dt.days / 365
bond_data['CouponFreq']=2
bond_data=bond_data.rename(columns={'Coupon (%)': 'Coupon'})
bond_data=bond_data.drop(columns=['Issuer','Actions'])
col = bond_data.pop('ShortName')
bond_data.insert(0, 'ShortName', col)

print(bond_data.head())
# Out:
#       ShortName  Coupon   Maturity   Price        Ttm  CouponFreq
# 0  GB0002404191    6.00 2028-12-07  113.74   5.668493           2
# 1  GB0030880693    5.00 2025-03-07  102.42   1.912329           2
# 2  GB00B24FF097    4.75 2030-12-07  109.76   7.668493           2
# 3  GB00B00NY175    4.75 2038-12-07  112.53  15.673973           2
# 4  GB00B52WS153    4.50 2034-09-07  109.59  11.421918           2

# %%
bond_data.head
# Out:
# <bound method NDFrame.head of        ShortName  Coupon   Maturity    Price        Ttm  CouponFreq
# 0   GB0002404191   6.000 2028-12-07  113.740   5.668493           2
# 1   GB0030880693   5.000 2025-03-07  102.420   1.912329           2
# 2   GB00B24FF097   4.750 2030-12-07  109.760   7.668493           2
# 3   GB00B00NY175   4.750 2038-12-07  112.530  15.673973           2
# 4   GB00B52WS153   4.500 2034-09-07  109.590  11.421918           2
# 5   GB00B1VWPJ53   4.500 2042-12-07  110.185  19.676712           2
# 6   GB00B3KJDS62   4.250 2039-09-07  106.240  16.424658           2
# 7   GB00B39R3707   4.250 2049-12-07  107.850  26.682192           2
# 8   GB00B16NNR78   4.250 2027-12-07  104.110   4.665753           2
# 9   GB00B128DP45   4.250 2046-12-07  106.945  23.679452           2
# 10  GB00B06YGN05   4.250 2055-12-07  110.185  32.684932           2
# 11  GB0032452392   4.250 2036-03-07  107.115  12.920548           2
# 12  GB0004893086   4.250 2032-06-07  107.405   9.169863           2
# 13  GB00B6460505   4.250 2040-12-07  106.380  17.676712           2
# 14  GB00BL6C7720   4.125 2027-01-29  101.820   3.810959           2
# 15  GB00B54QLM75   4.000 2060-01-22  107.770  36.813699           2
# 16  GB00B6RNH572   3.750 2052-07-22   99.980  29.306849           2
# 17  GB00BPCJD880   3.500 2025-10-22   99.400   2.539726           2
# 18  GB00BN65R313   3.500 2045-01-22   95.525  21.805479           2
# 19  GB00BBJNQY21   3.500 2068-07-22   99.010  45.317808           2
# 20  GB00BMV7TC88   3.250 2033-01-31   98.535   9.821918           2
# 21  GB00B84Z9V04   3.250 2044-01-22   92.105  20.802740           2
# 22  GB00BHBFH458   2.750 2024-09-07   98.460   1.416438           2
# 23  GB00BYYMZX75   2.500 2065-07-22   77.210  42.315068           2
# 24  GB0008983024   2.500 2024-07-17  374.630   1.273973           2
# 25  GB00B7Z53659   2.250 2023-09-07   99.250   0.413699           2
# 26  GB0031790826   2.000 2035-01-26  254.030  11.808219           2
# 27  GB00BTHH2R79   2.000 2025-09-07   96.590   2.416438           2
# 28  GB00BZB26Y51   1.750 2037-09-07   78.540  14.424658           2
# 29  GB00BFWFPP71   1.750 2049-01-22   66.965  25.808219           2
# 30  GB00BD0XH204   1.750 2057-07-22   63.490  34.309589           2
# 31  GB00BFX0ZL78   1.625 2028-10-22   91.800   5.542466           2
# 32  GB00BFMCN652   1.625 2071-10-22   57.685  48.569863           2
# 33  GB00BYZW3G56   1.500 2026-07-22   94.340   3.287671           2
# 34  GB00BM8Z2V59   1.500 2053-07-31   59.785  30.331507           2
# 35  GB00BDCHBW80   1.500 2047-07-22   63.965  24.301370           2
# 36  GB00BLH38158   1.250 2051-07-31   56.870  28.328767           2
# 37  GB00BJQWYH73   1.250 2041-10-22   66.800  18.550685           2
# 38  GB00BDRHNP05   1.250 2027-07-22   91.905   4.287671           2
# 39  GB00BLBDX619   1.125 2073-10-22   46.195  50.572603           2
# 40  GB00BFWFPL34   1.000 2024-04-22   97.040   1.038356           2
# 41  GB00BNNGP775   0.875 2046-01-31   55.810  22.830137           2
# 42  GB00BM8Z2S21   0.875 2033-07-31   77.815  10.317808           2
# 43  GB00BJMHB534   0.875 2029-10-22   85.960   6.542466           2
# 44  GB00BF0HZ991   0.750 2023-07-22   99.070   0.284932           2
# 45  GB00BMGR2916   0.625 2035-07-31   70.840  12.317808           2
# 46  GB00BMBL1F74   0.625 2050-10-22   46.990  27.556164           2
# 47  GB00BMBL1D50   0.500 2061-10-22   37.250  38.564384           2
# 48  GB00BLPK7227   0.500 2029-01-31   84.740   5.819178           2
# 49  GB00BNNGP668   0.375 2026-10-22   89.770   3.539726           2
# 50  GB00BL68HH02   0.375 2030-10-22   80.510   7.542466           2
# 51  GB00BMGR2809   0.250 2031-07-31   77.695   8.315068           2
# 52  GB00BLPK7110   0.250 2025-01-31   93.840   1.816438           2
# 53  GB00BNNGP882   0.125 2051-03-22   92.410  27.969863           2
# 54  GB00BNNGP551   0.125 2031-08-10  104.280   8.342466           2
# 55  GB00BMGR2791   0.125 2024-01-31   97.100   0.813699           2
# 56  GB00BMBL1G81   0.125 2028-01-31   85.990   4.816438           2
# 57  GB00BM8Z2W66   0.125 2073-03-22  103.350  49.986301           2
# 58  GB00BLH38265   0.125 2039-03-22   98.910  15.961644           2
# 59  GB00BL68HJ26   0.125 2026-01-30   91.510   2.813699           2
# 60  GB00B4JYZV64   0.000 2034-09-07   74.100  11.421918           2
# 61  GB0030884786   0.000 2025-03-07   92.800   1.912329           2
# 62  GB0009140269   0.000 2029-12-07   82.372   6.668493           2
# 63  GB00B1HYR000   0.000 2027-12-07   84.400   4.665753           2>

# %%
bond_data.columns
# Out:
# Index(['ShortName', 'Coupon', 'Maturity', 'Price', 'Ttm', 'CouponFreq'], dtype='object')

# %%
FACE_VALUE=100.0

# %%
import numpy_financial as npf
def calculate_ytm(coupon, face_value, years_to_maturity, price, coupon_freq):
    coupon = coupon / 100.0
    periods = years_to_maturity *coupon_freq
    ytm = npf.rate(nper=periods, pmt=coupon*face_value/coupon_freq, pv=-price, fv=face_value)* coupon_freq
    return ytm * 100.0

def calculate_accrued_interest(coupon:float, face_value:float, years_to_maturity:float, payment_frequency:int):
    coupon = coupon / 100.0
    periods = int(years_to_maturity * payment_frequency)
    days_in_period = int(365 / payment_frequency)
    days_since_last_coupon = datetime.datetime.now().timetuple().tm_yday % days_in_period
    coupon_payment = (face_value * coupon) / payment_frequency
    accrued_interest = coupon_payment * days_since_last_coupon / days_in_period
    return accrued_interest

def calculate_dirty_price(clean_price:float, accrued_interest:float):
    dirty_price = clean_price + accrued_interest
    return dirty_price

# %%
bond_data.head(1)
# Out:
#       ShortName  Coupon   Maturity   Price       Ttm  CouponFreq
# 0  GB0002404191     6.0 2028-12-07  113.74  5.668493           2

# %%
bond_data['AccruedInterest']=bond_data.apply(lambda x: calculate_accrued_interest(x['Coupon'],FACE_VALUE,x['Ttm'],x['CouponFreq']),axis=1)
bond_data['DirtyPrice']=bond_data.apply(lambda x: calculate_dirty_price(x['Price'],x['AccruedInterest']),axis=1)
bond_data['DirtyYield'] = bond_data.apply(lambda x: calculate_ytm(x['Coupon'], FACE_VALUE, x['Ttm'],x['DirtyPrice'],x['CouponFreq']), axis=1)
bond_data['CleanYield'] = bond_data.apply(lambda x: calculate_ytm(x['Coupon'], FACE_VALUE, x['Ttm'],x['Price'],x['CouponFreq']), axis=1)

# %%
bond_data.dtypes
# Out:
# ShortName                  object
# Coupon                    float64
# Maturity           datetime64[ns]
# Price                     float64
# Ttm                       float64
# CouponFreq                  int64
# AccruedInterest           float64
# DirtyPrice                float64
# DirtyYield                float64
# CleanYield                float64
# dtype: object

# %%
bond_data=bond_data.sort_values('Ttm')

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

bond_data_styler=bond_data.style.set_properties(**{'font-size': '6pt'})
bond_data_styler
# Out:
# <style type="text/css">
# #T_d5cd2_row0_col0, #T_d5cd2_row0_col1, #T_d5cd2_row0_col2, #T_d5cd2_row0_col3, #T_d5cd2_row0_col4, #T_d5cd2_row0_col5, #T_d5cd2_row0_col6, #T_d5cd2_row0_col7, #T_d5cd2_row0_col8, #T_d5cd2_row0_col9, #T_d5cd2_row1_col0, #T_d5cd2_row1_col1, #T_d5cd2_row1_col2, #T_d5cd2_row1_col3, #T_d5cd2_row1_col4, #T_d5cd2_row1_col5, #T_d5cd2_row1_col6, #T_d5cd2_row1_col7, #T_d5cd2_row1_col8, #T_d5cd2_row1_col9, #T_d5cd2_row2_col0, #T_d5cd2_row2_col1, #T_d5cd2_row2_col2, #T_d5cd2_row2_col3, #T_d5cd2_row2_col4, #T_d5cd2_row2_col5, #T_d5cd2_row2_col6, #T_d5cd2_row2_col7, #T_d5cd2_row2_col8, #T_d5cd2_row2_col9, #T_d5cd2_row3_col0, #T_d5cd2_row3_col1, #T_d5cd2_row3_col2, #T_d5cd2_row3_col3, #T_d5cd2_row3_col4, #T_d5cd2_row3_col5, #T_d5cd2_row3_col6, #T_d5cd2_row3_col7, #T_d5cd2_row3_col8, #T_d5cd2_row3_col9, #T_d5cd2_row4_col0, #T_d5cd2_row4_col1, #T_d5cd2_row4_col2, #T_d5cd2_row4_col3, #T_d5cd2_row4_col4, #T_d5cd2_row4_col5, #T_d5cd2_row4_col6, #T_d5cd2_row4_col7, #T_d5cd2_row4_col8, #T_d5cd2_row4_col9, #T_d5cd2_row5_col0, #T_d5cd2_row5_col1, #T_d5cd2_row5_col2, #T_d5cd2_row5_col3, #T_d5cd2_row5_col4, #T_d5cd2_row5_col5, #T_d5cd2_row5_col6, #T_d5cd2_row5_col7, #T_d5cd2_row5_col8, #T_d5cd2_row5_col9, #T_d5cd2_row6_col0, #T_d5cd2_row6_col1, #T_d5cd2_row6_col2, #T_d5cd2_row6_col3, #T_d5cd2_row6_col4, #T_d5cd2_row6_col5, #T_d5cd2_row6_col6, #T_d5cd2_row6_col7, #T_d5cd2_row6_col8, #T_d5cd2_row6_col9, #T_d5cd2_row7_col0, #T_d5cd2_row7_col1, #T_d5cd2_row7_col2, #T_d5cd2_row7_col3, #T_d5cd2_row7_col4, #T_d5cd2_row7_col5, #T_d5cd2_row7_col6, #T_d5cd2_row7_col7, #T_d5cd2_row7_col8, #T_d5cd2_row7_col9, #T_d5cd2_row8_col0, #T_d5cd2_row8_col1, #T_d5cd2_row8_col2, #T_d5cd2_row8_col3, #T_d5cd2_row8_col4, #T_d5cd2_row8_col5, #T_d5cd2_row8_col6, #T_d5cd2_row8_col7, #T_d5cd2_row8_col8, #T_d5cd2_row8_col9, #T_d5cd2_row9_col0, #T_d5cd2_row9_col1, #T_d5cd2_row9_col2, #T_d5cd2_row9_col3, #T_d5cd2_row9_col4, #T_d5cd2_row9_col5, #T_d5cd2_row9_col6, #T_d5cd2_row9_col7, #T_d5cd2_row9_col8, #T_d5cd2_row9_col9, #T_d5cd2_row10_col0, #T_d5cd2_row10_col1, #T_d5cd2_row10_col2, #T_d5cd2_row10_col3, #T_d5cd2_row10_col4, #T_d5cd2_row10_col5, #T_d5cd2_row10_col6, #T_d5cd2_row10_col7, #T_d5cd2_row10_col8, #T_d5cd2_row10_col9, #T_d5cd2_row11_col0, #T_d5cd2_row11_col1, #T_d5cd2_row11_col2, #T_d5cd2_row11_col3, #T_d5cd2_row11_col4, #T_d5cd2_row11_col5, #T_d5cd2_row11_col6, #T_d5cd2_row11_col7, #T_d5cd2_row11_col8, #T_d5cd2_row11_col9, #T_d5cd2_row12_col0, #T_d5cd2_row12_col1, #T_d5cd2_row12_col2, #T_d5cd2_row12_col3, #T_d5cd2_row12_col4, #T_d5cd2_row12_col5, #T_d5cd2_row12_col6, #T_d5cd2_row12_col7, #T_d5cd2_row12_col8, #T_d5cd2_row12_col9, #T_d5cd2_row13_col0, #T_d5cd2_row13_col1, #T_d5cd2_row13_col2, #T_d5cd2_row13_col3, #T_d5cd2_row13_col4, #T_d5cd2_row13_col5, #T_d5cd2_row13_col6, #T_d5cd2_row13_col7, #T_d5cd2_row13_col8, #T_d5cd2_row13_col9, #T_d5cd2_row14_col0, #T_d5cd2_row14_col1, #T_d5cd2_row14_col2, #T_d5cd2_row14_col3, #T_d5cd2_row14_col4, #T_d5cd2_row14_col5, #T_d5cd2_row14_col6, #T_d5cd2_row14_col7, #T_d5cd2_row14_col8, #T_d5cd2_row14_col9, #T_d5cd2_row15_col0, #T_d5cd2_row15_col1, #T_d5cd2_row15_col2, #T_d5cd2_row15_col3, #T_d5cd2_row15_col4, #T_d5cd2_row15_col5, #T_d5cd2_row15_col6, #T_d5cd2_row15_col7, #T_d5cd2_row15_col8, #T_d5cd2_row15_col9, #T_d5cd2_row16_col0, #T_d5cd2_row16_col1, #T_d5cd2_row16_col2, #T_d5cd2_row16_col3, #T_d5cd2_row16_col4, #T_d5cd2_row16_col5, #T_d5cd2_row16_col6, #T_d5cd2_row16_col7, #T_d5cd2_row16_col8, #T_d5cd2_row16_col9, #T_d5cd2_row17_col0, #T_d5cd2_row17_col1, #T_d5cd2_row17_col2, #T_d5cd2_row17_col3, #T_d5cd2_row17_col4, #T_d5cd2_row17_col5, #T_d5cd2_row17_col6, #T_d5cd2_row17_col7, #T_d5cd2_row17_col8, #T_d5cd2_row17_col9, #T_d5cd2_row18_col0, #T_d5cd2_row18_col1, #T_d5cd2_row18_col2, #T_d5cd2_row18_col3, #T_d5cd2_row18_col4, #T_d5cd2_row18_col5, #T_d5cd2_row18_col6, #T_d5cd2_row18_col7, #T_d5cd2_row18_col8, #T_d5cd2_row18_col9, #T_d5cd2_row19_col0, #T_d5cd2_row19_col1, #T_d5cd2_row19_col2, #T_d5cd2_row19_col3, #T_d5cd2_row19_col4, #T_d5 ...

# %%
bond_data.to_excel(r"c:\temp\bond_data.xlsx", index=False)

# %%
# yield filtering 
df_less_than_Ttm = bond_data[bond_data['Ttm'] < 5]

# %%
df_less_than_Ttm=df_less_than_Ttm.sort_values("DirtyYield", ascending=False)
cols = ['ShortName', 'Coupon', 'Maturity', 'Price', 'Ttm','DirtyPrice', 'DirtyYield', 'CleanYield']
df_less_than_Ttm = df_less_than_Ttm[cols]
df_less_than_Ttm
# Out:
#        ShortName  Coupon   Maturity    Price       Ttm  DirtyPrice  \
# 61  GB0030884786   0.000 2025-03-07   92.800  1.912329   92.800000
# 52  GB00BLPK7110   0.250 2025-01-31   93.840  1.816438   93.907308
# 55  GB00BMGR2791   0.125 2024-01-31   97.100  0.813699   97.133654
# 63  GB00B1HYR000   0.000 2027-12-07   84.400  4.665753   84.400000
# 40  GB00BFWFPL34   1.000 2024-04-22   97.040  1.038356   97.309231
# 49  GB00BNNGP668   0.375 2026-10-22   89.770  3.539726   89.870962
# 17  GB00BPCJD880   3.500 2025-10-22   99.400  2.539726  100.342308
# 44  GB00BF0HZ991   0.750 2023-07-22   99.070  0.284932   99.271923
# 22  GB00BHBFH458   2.750 2024-09-07   98.460  1.416438   99.200385
# 14  GB00BL6C7720   4.125 2027-01-29  101.820  3.810959  102.930577
# 59  GB00BL68HJ26   0.125 2026-01-30   91.510  2.813699   91.543654
# 56  GB00BMBL1G81   0.125 2028-01-31   85.990  4.816438   86.023654
# 27  GB00BTHH2R79   2.000 2025-09-07   96.590  2.416438   97.128462
# 38  GB00BDRHNP05   1.250 2027-07-22   91.905  4.287671   92.241538
# 33  GB00BYZW3G56   1.500 2026-07-22   94.340  3.287671   94.743846
# 8   GB00B16NNR78   4.250 2027-12-07  104.110  4.665753  105.254231
# 1   GB0030880693   5.000 2025-03-07  102.420  1.912329  103.766154
# 25  GB00B7Z53659   2.250 2023-09-07   99.250  0.413699   99.855769
# 24  GB0008983024   2.500 2024-07-17  374.630  1.273973  375.303077
#
#     DirtyYield  CleanYield
# 61    3.945884    3.945884
# 52    3.751112    3.791398
# 55    3.734184    3.777579
# 63    3.668292    3.668292
# 40    3.664657    3.937293
# 49    3.438719    3.471219
# 17    3.358261    3.749880
# 44    3.338713    4.065951
# 22    3.332644    3.877871
# 14    3.300321    3.609540
# 59    3.296647    3.309951
# 56    3.286230    3.294512
# 27    3.245147    3.483645
# 38    3.200911    3.289711
# 33    3.196970    3.331883
# 8     3.033787    3.292504
# 1     2.959799    3.677907
# 25    2.602781    4.096825
# 24  -79.929764  -79.844737

# %%
import requests
from bs4 import BeautifulSoup
from googlesearch import search

# Replace ISIN below with the actual ISIN you want to look up
isin = "GB00B7S7QJ66"

# Build the query to search for the gilt on Google
query = f"{isin} site:londonstockexchange.com"

# Use Google search to get the URL of the page for the gilt
url = next((result for result in search(query, num_results=3) if "londonstockexchange.com" in result and "ads.google.com" not in result), None)

if url is None:
    raise ValueError("Could not find a matching page on London Stock Exchange website")

# Make a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the response using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the element that contains the last price
price_element = soup.find("span", {"class": "price-truncate__price"})

# Extract the text of the last price from the element
last_price = price_element.text.strip()

print(f"The last price of {isin} is {last_price}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9 query = f"{isin} site:londonstockexchange.com"
#      11 # Use Google search to get the URL of the page for the gilt
# ---> 12 url = next((result for result in search(query, num_results=3) if "londonstockexchange.com" in result and "ads.google.com" not in result), None)
#      14 if url is None:
#      15     raise ValueError("Could not find a matching page on London Stock Exchange website")
#
# Cell In[6], line 12, in <genexpr>(.0)
#       9 query = f"{isin} site:londonstockexchange.com"
#      11 # Use Google search to get the URL of the page for the gilt
# ---> 12 url = next((result for result in search(query, num_results=3) if "londonstockexchange.com" in result and "ads.google.com" not in result), None)
#      14 if url is None:
#      15     raise ValueError("Could not find a matching page on London Stock Exchange website")
#
# File C:\apps\Miniconda3\envs\bondsParseEnv\Lib\site-packages\googlesearch\__init__.py:54, in search(term, num_results, lang, proxy, advanced, sleep_interval, timeout)
#      51 start = 0
#      52 while start < num_results:
#      53     # Send request
# ---> 54     resp = _req(escaped_term, num_results - start,
#      55                 lang, start, proxies, timeout)
#      57     # Parse
#      58     soup = BeautifulSoup(resp.text, "html.parser")
#
# File C:\apps\Miniconda3\envs\bondsParseEnv\Lib\site-packages\googlesearch\__init__.py:23, in _req(term, results, lang, start, proxies, timeout)
#       8 def _req(term, results, lang, start, proxies, timeout):
#       9     resp = get(
#      10         url="https://www.google.com/search",
#      11         headers={
#    (...)
#      21         timeout=timeout,
#      22     )
# ---> 23     resp.raise_for_status()
#      24     return resp
#
# File C:\apps\Miniconda3\envs\bondsParseEnv\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DGB00B7S7QJ66%252Bsite%253Alondonstockexchange.com%26num%3D5%26hl%3Den%26start%3D0&hl=en&q=EgRShOoBGLzCxaEGIjDEisBR_2VN5dcNDqWC0KFbW_aop8aX4RMGmKCDXmULRMlXR-P8q5mOcpBoi4bnLsMyAXI

# %%
# !pip install googlesearch-python
# Out:
# Requirement already satisfied: googlesearch-python in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (1.2.3)
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from googlesearch-python) (4.12.0)
# Requirement already satisfied: requests>=2.20 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from googlesearch-python) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from requests>=2.20->googlesearch-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from requests>=2.20->googlesearch-python) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from requests>=2.20->googlesearch-python) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\apps\miniconda3\envs\bondsparseenv\lib\site-packages (from requests>=2.20->googlesearch-python) (2022.12.7)
